# %%
import pandas as pd

from statsbombpy import sb

from mplsoccer import Pitch

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 65              55         43         Europe           UEFA Euro
# 66              35         75         Europe  UEFA Europa League
# 67              53        106         Europe   UEFA Women's Euro
# 68              72        107  International   Women's World Cup
# 69              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
sb.matches(competition_id=43, season_id=106).head(50)
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 0    3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1    3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2    3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
# 3    3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 4    3857288  2022-11-26  12:00:00.000  International - FIFA World Cup   2022
# 5    3857267  2022-11-29  17:00:00.000  International - FIFA World Cup   2022
# 6    3869321  2022-12-09  21:00:00.000  International - FIFA World Cup   2022
# 7    3857287  2022-11-24  15:00:00.000  International - FIFA World Cup   2022
# 8    3869486  2022-12-10  17:00:00.000  International - FIFA World Cup   2022
# 9    3869685  2022-12-18  17:00:00.000  International - FIFA World Cup   2022
# 10   3857260  2022-11-30  21:00:00.000  International - FIFA World Cup   2022
# ...

# %%
MATCH_ID = 3869685

# %%
match_events_df = sb.events(match_id=MATCH_ID)

# %%
match_360_df = pd.read_json(f'C:/Users/suubc/statsbombpy/three-sixty/{MATCH_ID}.json')

# %%
match_events_df['id']
# Out:
# 0       0584ee21-e3dd-4d9f-95a0-5b5e84be25c3
# 1       b32679f8-942e-4122-96a2-015caf75e628
# 2       954f6855-de22-46a2-8d09-6fe94eec2b9b
# 3       6404a8e8-afaf-489d-b65e-173a237ffed5
# 4       e84fb5b3-270f-4427-bf97-1a6eaec7285f
#                         ...
# 4402    da654dbc-5e9d-4067-ab4a-2db561a77c8f
# 4403    0e712309-2130-4ad9-ab32-cda2e26c4d0b
# 4404    4f66bdf1-2c51-483a-b45a-89b525bc23c0
# 4405    ed616313-3980-444e-805f-9951a40d8a52
# 4406    ad6e8237-8cb9-44f4-b9fb-356f066f3b2b
# Name: id, Length: 4407, dtype: object

# %%
match_360_df['event_uuid']
# Out:
# 0       f651a6c4-55e3-4e0f-a178-59414ba83d6a
# 1       97b5dc82-547a-4f93-a632-a2a8daf5ac98
# 2       9707e590-1d55-4d25-a50f-475019356152
# 3       a5956ecc-d637-44d2-8705-e2079e12013e
# 4       5ba6dfab-49f0-4225-bbb6-8b1e27bc729a
#                         ...
# 3678    97439112-dfb5-4bd5-9967-554095296096
# 3679    50dcde1a-faa3-4eec-a0cd-3f09a7cf763a
# 3680    54e27ba9-b9ae-44a3-ac8d-fc91e76a1b91
# 3681    bcc6d4ae-f71c-4566-bf2d-c12f910eb526
# 3682    66eaf262-999f-4953-a924-f1b596de4dbf
# Name: event_uuid, Length: 3683, dtype: object

# %%
match_360_df.head()
# Out:
#                              event_uuid  \
# 0  f651a6c4-55e3-4e0f-a178-59414ba83d6a
# 1  97b5dc82-547a-4f93-a632-a2a8daf5ac98
# 2  9707e590-1d55-4d25-a50f-475019356152
# 3  a5956ecc-d637-44d2-8705-e2079e12013e
# 4  5ba6dfab-49f0-4225-bbb6-8b1e27bc729a
#
#                                         visible_area  \
# 0  [8.98496759714251, 80.0, 41.4622037211361, 0.0...
# 1  [8.74654439366353, 80.0, 40.9967310870193, 0.0...
# 2  [8.74654439366353, 80.0, 40.9967310870193, 0.0...
# 3  [10.227276315524, 80.0, 41.5155332886657, 0.0,...
# 4  [13.2232254880239, 80.0, 0.0, 65.4802459369524...
#
#                                         freeze_frame
# 0  [{'teammate': True, 'actor': False, 'keeper': ...
# 1  [{'teammate': True, 'actor': False, 'keeper': ...
# 2  [{'teammate': True, 'actor': False, 'keeper': ...
# 3  [{'teammate': True, 'actor': False, 'keeper': ...
# 4  [{'teammate': True, 'actor': False, 'keeper': ...

# %%
match_360_df.iloc[0]['freeze_frame']
# Out:
# [{'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [39.21695730971832, 44.77861301106889]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [39.2235613627218, 29.49684745718256]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [42.57667276588051, 67.52374056870202]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [46.549119819701936, 12.613254283667075]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [47.79830626119247, 43.13070641887103]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [55.67397005317026, 35.36721508054195]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [60.37812766957068, 75.33968683204978]},
#  {'teammate': True,
#   'actor': False,
#   'keeper': False,
#   'location': [60.521497629167975, 20.128734327624308]},
#  {'teammate': True,
# ...

# %%
df= pd.merge(left=match_events_df, right=match_360_df,  left_on='id', right_on='event_uuid', how='left')

# %%
df.head(5)
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part  ...  \
# ...

# %%
df.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot', 'clearance_other', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_penalty', 'foul_committed_type', 'foul_won_advantage',
#        'foul_won_defensive', 'foul_won_penalty', 'goalkeeper_body_part',
#        'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'interception_outcome', 'location', 'match_id', 'minute', 'off_camera',
# ...

# %%
df.player_id.unique()
# Out:
# array([   nan,  5487., 10481., 29201.,  7797., 20572.,  3090.,  5507.,
#         6909.,  6704.,  3026.,  5485.,  4445., 27886.,  5503.,  2995.,
#         3099.,  3604., 38718.,  3009.,  5477., 29560.,  8519., 22097.,
#         2972., 19597., 24778.,  8217., 28263., 11990., 16308., 11456.,
#        11135.,  5743.,  7161.])

# %%
# df.player ile oyunculara bakıyoruz ve df.player_id ile o sıradakı oyuncuyu aratıp player id sini alıyoruz
# df.player[36] ve df.player_id[36] şeklinde


df.player[36]
# Out:
# 'Lionel Andrés Messi Cuccittini'

# %%
df.player_id[36]
# Out:
# 5503.0

# %%
MESSI = 5503

df_messi_pass = df[(df['player_id'] == MESSI) & (df['type'] == 'Pass')].reset_index(drop=True)

# %%
# df_messi_pass.player_id hepsi aynı id mi kontrolü

# %%
df_messi_pass.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part  ...  \
# ...

# %%
df_messi_pass.location
# Out:
# 0      [76.6, 35.7]
# 1      [99.3, 57.3]
# 2      [67.9, 59.0]
# 3      [81.8, 65.2]
# 4      [39.2, 48.1]
# 5     [120.0, 80.0]
# 6     [108.2, 74.4]
# 7      [80.5, 47.8]
# 8      [52.5, 56.4]
# 9      [95.2, 48.5]
# 10     [89.3, 58.8]
# 11     [89.5, 65.0]
# 12    [120.0, 80.0]
# 13     [81.8, 38.6]
# 14     [45.8, 59.4]
# 15     [68.1, 54.5]
# 16     [92.7, 47.6]
# 17     [80.3, 57.7]
# 18     [52.9, 61.8]
# 19     [48.0, 42.5]
# 20     [44.6, 28.4]
# 21     [37.5, 53.8]
# 22     [80.3, 56.4]
# 23     [82.0, 22.8]
# 24     [61.0, 40.1]
# 25     [70.6, 21.1]
# 26    [100.4, 65.2]
# 27     [81.3, 32.9]
# 28     [77.5, 74.6]
# 29     [92.4, 60.9]
# 30    [120.0, 80.0]
# 31     [67.6, 71.8]
# 32     [64.0, 43.4]
# 33     [74.7, 19.8]
# 34      [97.8, 9.6]
# 35     [57.6, 59.6]
# 36     [32.6, 72.9]
# 37    [106.8, 23.9]
# 38     [49.0, 66.5]
# 39     [85.6, 72.7]
# 40     [86.7, 76.1]
# 41     [92.9, 64.8]
# 42     [61.0, 40.1]
# 43     [75.8, 60.3]
# 44     [94.6, 61.1]
# ...

# %%
df_messi_pass[['x_start','y_start']] = pd.DataFrame(df_messi_pass.location.tolist(), index=df_messi_pass.index)
df_messi_pass[['x_end','y_end']] = pd.DataFrame(df_messi_pass.pass_end_location.tolist(), index=df_messi_pass.index)

# %%
# saha yapma ve pas plot gösterme

# %%
# saha görünüm
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(12,8))

# %%
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(12,8))


# messinin pas atmaya başladığı noktalar
p.scatter(x=df_messi_pass['x_start'], y=df_messi_pass['y_start'], ax=ax)


p.lines(xstart=df_messi_pass['x_start'], ystart=df_messi_pass['y_start'], xend=df_messi_pass['x_end'], yend=df_messi_pass['y_end'], ax=ax, comet=True)

# %%
df_messi_pass.iloc[0]
# Out:
# 50_50                                                                           NaN
# bad_behaviour_card                                                              NaN
# ball_receipt_outcome                                                            NaN
# ball_recovery_offensive                                                         NaN
# ball_recovery_recovery_failure                                                  NaN
#                                                         ...
# freeze_frame                      [{'teammate': False, 'actor': False, 'keeper':...
# x_start                                                                        76.6
# y_start                                                                        35.7
# x_end                                                                         116.2
# y_end                                                                           8.9
# Name: 0, Length: 99, dtype: object

# %%
# kendi takımı ve rakip takım ile ilgili oyuncularun gözüktüğü hall

# %%
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(12,8))


# messinin pas atmaya başladığı noktalar
p.scatter(x=df_messi_pass['x_start'], y=df_messi_pass['y_start'], ax=ax)


p.lines(xstart=df_messi_pass['x_start'], ystart=df_messi_pass['y_start'], xend=df_messi_pass['x_end'], yend=df_messi_pass['y_end'], ax=ax, comet=True)

for x in df_messi_pass.iloc[0]['freeze_frame']:
    if x['teammate']:
        color = 'green'
    else:
        color='red'

    p.scatter(x=x['location'][0], y=x['location'][1], ax=ax, c=color, s=100)

# %%
# ilk  pas için

# %%
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(12,8))

# ilk pas
df_ilk_pass = df_messi_pass[0:1]

# messinin pas atmaya başladığı noktalar
p.scatter(x=df_ilk_pass['x_start'], y=df_ilk_pass['y_start'], ax=ax)


p.lines(xstart=df_ilk_pass['x_start'], ystart=df_ilk_pass['y_start'], xend=df_ilk_pass['x_end'], yend=df_ilk_pass['y_end'], ax=ax, comet=True)

for x in df_ilk_pass.iloc[0]['freeze_frame']:
    if x['teammate']:
        color = 'green'
    else:
        color='red'

    p.scatter(x=x['location'][0], y=x['location'][1], ax=ax, c=color, s=100)
